# %%
from ews.models import *
import pandas as pd
import geojson
import numpy as np
import datetime

# %%
d = pd.read_csv("D:/DWC_plattform/metadata_clean.csv")

# %%
d = d[d["SiteType"]=="BathingSpot"]

# %%
d
# Out:
#                   SiteName      SiteReferencementName     SiteType SourceID  \
# 0  neuilly_sur_marne_smv17  SMV17 - Neuilly-sur-Marne  BathingSpot      SMV
# 1           chenneviere_si                Chenneviere  BathingSpot    SIAAP
# 2           pont_d'iéna_rg           Pont d'Iéna (RG)  BathingSpot      VDP
# 3        pont_de_l'alma_rg        Pont de l'Alma (RG)  BathingSpot      VDP
# 4           marne_dwc_2019             Marne_DWC_2019  BathingSpot    SIAAP
# 5       pont_alma_dwc_2019         Pont Alma_DWC_2019  BathingSpot    SIAAP
#
#    SiteLatitude(y)  SiteLongitude(x)
# 0        48.852620          2.522907
# 1        48.790690          2.521590
# 2        48.859478          2.292624
# 3        48.863021          2.301786
# 4        48.853460          2.530100
# 5        48.863020          2.305000

# %%
for index, row in d.iterrows():
    loc = Site()
    loc.name = row['SiteName']
    loc.ref_name = row['SiteReferencementName']
    loc.geom = {"coordinates": [row['SiteLongitude(x)'],row['SiteLatitude(y)']], "type": "Point"}
    loc.feature_type = FeatureType.objects.get(name = row['SiteType'])
    loc.owner = User.objects.get(id = 1)
    try:
        loc.save()
    except:
        print(loc)

# %%
data = pd.read_csv("D:/DigitalWaterCity/data_processed/FIB_lab_daily.csv", parse_dates = True, 
                   index_col = "date", dayfirst = True)

# %%
data = data.reset_index()

# %%
data
# Out:
#           date               name  value parameter
# 0   2016-07-04  pont_de_l'alma_rg   2087    E.coli
# 1   2016-07-12  pont_de_l'alma_rg    782    E.coli
# 2   2016-07-19  pont_de_l'alma_rg   1638    E.coli
# 3   2016-07-26  pont_de_l'alma_rg    875    E.coli
# 4   2016-08-02  pont_de_l'alma_rg   1716    E.coli
# ..         ...                ...    ...       ...
# 324 2019-09-24     pont_d'iena_rg   3843    E.coli
# 325 2019-09-25     pont_d'iena_rg   3114    E.coli
# 326 2019-09-26     pont_d'iena_rg   2639    E.coli
# 327 2019-09-27     pont_d'iena_rg   2029    E.coli
# 328 2019-09-30     pont_d'iena_rg    661    E.coli
#
# [329 rows x 4 columns]

# %%
#FeatureType.objects.get(name = 'BathingSpot').delete()

# %%
x = data.duplicated(subset=["name", "date"])

# %%
sum(x)
# Out:
# 0

# %%
data = data.dropna()

# %%
data
# Out:
#           date               name  value parameter
# 0   2016-07-04  pont_de_l'alma_rg   2087    E.coli
# 1   2016-07-12  pont_de_l'alma_rg    782    E.coli
# 2   2016-07-19  pont_de_l'alma_rg   1638    E.coli
# 3   2016-07-26  pont_de_l'alma_rg    875    E.coli
# 4   2016-08-02  pont_de_l'alma_rg   1716    E.coli
# ..         ...                ...    ...       ...
# 324 2019-09-24     pont_d'iena_rg   3843    E.coli
# 325 2019-09-25     pont_d'iena_rg   3114    E.coli
# 326 2019-09-26     pont_d'iena_rg   2639    E.coli
# 327 2019-09-27     pont_d'iena_rg   2029    E.coli
# 328 2019-09-30     pont_d'iena_rg    661    E.coli
#
# [329 rows x 4 columns]

# %%
for index, row in data.iterrows():
    dpoint = FeatureData()
    dpoint.date = row["date"]
    dpoint.value = row["value"]
    dpoint.site = Site.objects.get(name = row['name'])
    try:
        dpoint.save()
    except:
        print("{} already exists".format(dpoint.date))
# Out:
# 2016-07-04 00:00:00 already exists
# 2016-07-12 00:00:00 already exists
# 2016-07-19 00:00:00 already exists
# 2016-07-26 00:00:00 already exists
# 2016-08-02 00:00:00 already exists
# 2016-08-09 00:00:00 already exists
# 2016-08-16 00:00:00 already exists
# 2016-08-23 00:00:00 already exists
# 2016-08-30 00:00:00 already exists
# 2016-09-06 00:00:00 already exists
# 2016-09-12 00:00:00 already exists
# 2016-09-20 00:00:00 already exists
# 2016-09-27 00:00:00 already exists
# 2017-06-07 00:00:00 already exists
# 2017-06-13 00:00:00 already exists
# 2017-06-20 00:00:00 already exists
# 2017-06-27 00:00:00 already exists
# 2017-07-04 00:00:00 already exists
# 2017-07-11 00:00:00 already exists
# 2017-07-18 00:00:00 already exists
# 2017-07-25 00:00:00 already exists
# 2017-08-01 00:00:00 already exists
# 2017-08-08 00:00:00 already exists
# 2017-08-16 00:00:00 already exists
# 2017-08-22 00:00:00 already exists
# 2017-08-29 00:00:00 already exists
# 2017-09-05 00:00:00 already exists
# 2017-09-12 00:00:00 already exists
# 2017-09-19 00:00:00 already exists
# 2017-09-26 00:00:00 already exists
# 2018-06-12 00:00:00 already exists
# 2018-06-19 00:00:00 already exists
# 2018-06-26 00:00:00 already exists
# 2018-07-03 00:00:00 already exists
# 2018-07-10 00:00:00 already exists
# 2018-07-17 00:00:00 already exists
# 2018-07-24 00:00:00 already exists
# 2018-07-31 00:00:00 already exists
# 2018-08-07 00:00:00 already exists
# 2018-08-14 00:00:00 already exists
# 2018-08-21 00:00:00 already exists
# 2018-08-28 00:00:00 already exists
# 2018-09-04 00:00:00 already exists
# 2018-09-11 00:00:00 already exists
# 2018-09-18 00:00:00 already exists
# 2018-09-25 00:00:00 already exists
# 2019-06-04 00:00:00 already exists
# 2019-06-11 00:00:00 already exists
# 2019-06-18 00:00:00 already exists
# 2019-06-25 00:00:00 already exists
# 2019-07-02 00:00:00 already exists
# 2019-07-09 00:00:00 already exists
# 2019-07-16 00:00:00 already exists
# 2019-07-23 00:00:00 already exists
# 2019-07-30 00:00:00 already exists
# 2019-08-06 00:00:00 already exists
# 2019-08-13 00:00:00 already exists
# 2019-08-20 00:00:00 already exists
# 2019-08-27 00:00:00 already exists
# 2019-09-03 00:00:00 already exists
# 2019-09-10 00:00:00 already exists
# 2019-09-17 00:00:00 already exists
# 2019-09-24 00:00:00 already exists
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2016-06-14 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2016-06-21 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2016-06-29 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-02 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-06 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-08 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-09 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-12 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-14 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-15 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-16 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-19 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-21 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-22 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-23 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-28 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-29 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-06-30 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-07-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-07-05 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-07-06 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-07-07 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-07-10 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-07-12 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-07-13 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (2017-07-17 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# C:\Users\wolfg\miniconda3\envs\DWC\lib\site-packages\django\db\models\fields\__init__.py:1367: RuntimeWarning: DateTimeField FeatureData.date received a naive datetime (